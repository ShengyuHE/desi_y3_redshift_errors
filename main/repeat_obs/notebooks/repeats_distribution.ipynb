# %% [markdown]
# ## Plot the redshift erros distribution
#
# 1. Plot the redshift errors distribution for all tracers
# 2. Study the Z-dependece, especailly for QSO
# 3. The variance of the repeats samples

# %%
import os, sys
os.environ["MPICH_GPU_SUPPORT_ENABLED"] = "0"
import random
import fitsio
import numpy as np
from astropy.table import Table,join,unique,vstack
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mockfactory import Catalog
from matplotlib import ticker
from matplotlib.cm import get_cmap
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import random

import matplotlib as mpl
mpl.rcParams.update({
    "text.usetex": False,
    "mathtext.fontset": "cm",   # Computer Modern-like math
    "font.family": "serif",
})

sys.path.append('../../')
from helper import REDSHIFT_BIN_GLOBAL, REDSHIFT_BIN_ABACUSHF_V2, REDSHIFT_BIN_LSS
from plotting_tools import COLOR_OVERALL, COLOR_TRACER_GRADIENT, get_namespace
from dv_tools import set_edges, get_repeats_dv, get_cthr, sample_from_cdf_v1, sample_from_cdf_v2, get_cthr, get_dv_qu
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# save the figure to the overleaf or not
save_fig = True

OVERLEAF_DIR = '/global/homes/s/shengyu/Y3/desi_y3_redshift_errors/overleaf/figures'
RESULT_DIR = '../results'

# %%
# plot the overall dv distribution
fig = plt.figure(figsize=(12, 8))
gs = gridspec.GridSpec(2,2,wspace=0.14,hspace=0.25)

ls_err = '-'
alpha = 0.13
ls_repeat = '-'
lw_repeat = 0.9

tracers = ['BGS', 'LRG', 'ELG', 'QSO'][:]
for idx, tracer in enumerate(tracers):
    (zmin, zmax) = REDSHIFT_BIN_GLOBAL[tracer[:3]]
    color = COLOR_OVERALL[tracer[:3]]
    ax = plt.subplot(gs[idx])
    dv_rep, qu = get_repeats_dv(tracer[:3], zmin, zmax, kind='Z1/Z2')
    cthr = qu['cthr']
    # print(tracer, 'z',(zmin, zmax), f"MED:{qu['med']:.2f}", f"RMS:{qu['rms']:.2f}", f"fc:{qu['fc']:.2f}%")
    # ===== main panel (log10 |dv|) =====
    catasmin, catasmax, catasbin = -4.5, 6., 0.2
    ax.hist(np.log10(abs(dv_rep)), bins=np.arange(catasmin, catasmax, catasbin), 
            lw = 1.4, color= color, density=True, ls=ls_repeat, alpha=alpha)
    dv_err= sample_from_cdf_v2(tracer, zmin, zmax, len(dv_rep), seed = 1)
    qu_err = get_dv_qu(dv_err, cthr)
    print(qu_err)
    ax.hist(np.log10(abs(dv_err)), histtype='step', bins=np.arange(catasmin, catasmax, catasbin), 
            lw = lw_repeat, color= color, density=True, ls=ls_err)
    # ax.axvline(x=np.log10(qu['med']), color=color, linestyle='--', linewidth=1.2) # Median of dv
    # ax.axvline(x=np.log10(qu['rms']), color=color, linestyle=':', linewidth=1.2) # RMS of dv
    ax.axvline(np.log10(cthr), color=color, linestyle=':', linewidth=1.5) # catastrophic therehold
    # if tracer == 'QSO':
        # ax.axvline(x=np.log10(3000), color='black', linestyle='-', linewidth=1.2, alpha=0.3)    
    ax.axvspan(np.log10(cthr), 7, color='darkblue', alpha=0.05, zorder=0)
    if idx == 0:
        legend_handles = []
        for tr in tracers:
            legend_handles += [Line2D([0], [0], color=COLOR_OVERALL[tr[:3]], lw=2, ls='-', label=tr[:3]),]
            # legend_handles += [Patch(facecolor=COLOR_OVERALL[tr[:3]], edgecolor=COLOR_OVERALL[tr[:3]], alpha=0.3, label=f'{tr[:3]}')]
        ax.legend(handles=legend_handles, loc=2, fontsize=12, frameon=False)
    if idx == 1:
        # plot axes settings
        legend_handles = [
            Line2D([0], [0], color='black', lw=1.4, ls=ls_err, label=r'redshift errors $(v_{\rm{err}})$'),
           Patch(facecolor='black', edgecolor='black', alpha=alpha, label=r'repeats ($\Delta v_{\rm{ij}}$)'),
        ]
        ax.legend(handles=legend_handles, loc=2, fontsize=11.5, frameon=False)
    if idx == 3:
        # plot axes settings
        legend_handles = [Line2D([0], [0], color='black', lw=1.4, ls=':', alpha=0.7, label='catastrophic cut'),]
        ax.legend(handles=legend_handles, loc=2, fontsize=12, frameon=False)
    # ax.set_xlabel(r'$| \, \Delta s_{\mathrm{error}} \, | \, \rm{[km/s]}$', fontsize=11)
    ax.set_xlabel(r'$\log_{10}|\,\Delta v\,| \, \rm{[km/s]}$', fontsize=15)
    ax.set_yscale('log')
    if idx in [0,2]:
        ax.set_ylabel(r'Normalized counts', fontsize = 13)
    ax.set_xlim(catasmin, catasmax)
    # ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    # ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: fr"$10^{{{int(x)}}}$"))
    ax.tick_params(axis='both', labelsize=12)
    # ===== inset panel (linear |dv|) =====
    # position: [left, bottom, width, height] in axes fraction
    ax_in = inset_axes(ax, width="90%", height="85%", loc="upper left",
                       bbox_to_anchor=(0.04, 0.02, 0.45, 0.45), bbox_transform=ax.transAxes, borderpad=0)
    bins = np.linspace(-cthr, cthr, 70)
    ax_in.hist(dv_rep[abs(dv_rep) < cthr], bins = bins, lw=1.0, color=color, density=True, ls='--', alpha=alpha)
    ax_in.hist(dv_err[abs(dv_err) < cthr], bins = bins, histtype='step', lw=0.8, color=color, density=True, ls=ls_err)
    # cosmetics for inset
    ax_in.set_yscale('log')  # set the log scale
    ax_in.tick_params(axis='both', which='both', labelsize=11, length=2)
    # keep inset clean: no labels, maybe a tiny note
    if tracer[:3] in ['BGS']:
        ax_in.set_xticks([0, -500, 500])
        ax_in.set_xticklabels(['0', '-500', '500'], fontsize=10)
        ax_in.set_ylim(10**(-6.2), 10**(-1.))
        ax_in.set_xlim(-cthr*0.9, cthr*0.9)
    elif tracer in ['LRG']:
        ax_in.set_xticks([0, -1000, 1000])
        ax_in.set_xticklabels(['0', '-1000', '1000'], fontsize=10)
        ax_in.set_ylim(10**(-7.2), 10**(-1.))
        ax_in.set_xlim(-cthr*0.9, cthr*0.9)
    elif tracer in ['ELG']:
        ax_in.set_xticks([0, -500, 500])
        ax_in.set_xticklabels(['0', '-500', '500'], fontsize=10)
        ax_in.set_ylim(10**(-7.5), 10**(-1.))
        ax_in.set_xlim(-cthr*0.9, cthr*0.9)
    elif tracer == 'QSO':
        ax_in.set_xticks([0, -5000, 5000])
        ax_in.set_xticklabels(['0', '-5000', '5000'], fontsize=10)
        ax_in.set_ylim(10**(-8), 10**(-1.))
        ax_in.set_xlim(-cthr*0.9, cthr*0.9)
    ax_in.set_yticklabels([])
    # ax_in.set_title('linear scale', fontsize=12, pad=2, loc='left')
    for spine in ['top','right','left','bottom']:
        ax_in.spines[spine].set_linewidth(0.8)
    for label in ax_in.get_xticklabels():
        label.set_bbox(dict(facecolor='white', edgecolor='none', pad=0.8, alpha=0.9))
        label.set_zorder(10)
if save_fig == True:
    plt.savefig(OVERLEAF_DIR+f'/hist_redshift_errors.pdf', bbox_inches='tight')
# Out:
# [000039.17]  07-07 09:09  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_BGS_z0.1-0.4.npz to generate redshift errors
# {'cthr': 600, 'mad': 17.42245206790548, 'rms': 29.61945214274697, 'fc': 0.25487873950877915}
# [000039.54]  07-07 09:09  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_LRG_z0.4-1.1.npz to generate redshift errors
# {'cthr': 2000, 'mad': 33.45795814897839, 'rms': 59.85995054518688, 'fc': 0.17571520334655177}
# [000040.25]  07-07 09:09  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_ELG_z0.8-1.6.npz to generate redshift errors
# {'cthr': 600, 'mad': 6.547258372078039, 'rms': 18.942375338393145, 'fc': 0.1193658931528495}
# [000040.81]  07-07 09:09  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z0.8-2.1.npz to generate redshift errors
# {'cthr': 10000, 'mad': 58.438482814915275, 'rms': 329.49525136877804, 'fc': 0.3405479037384592}

# %%
# plot the dv distribution
tracers = ['BGS', 'LRG', 'ELG', 'QSO'][:]
fig = plt.figure(figsize=(15, 3))
gs = gridspec.GridSpec(1, 4, wspace=0.05, hspace=0.1)

for indt, tracer in enumerate(tracers):
    cthr = get_cthr(tracer)
    (zmin, zmax) = REDSHIFT_BIN_GLOBAL[tracer]
    z_edges = np.arange(zmin, zmax+0.05, 0.1)
    zbins = list(zip(z_edges[:-1], z_edges[1:]))
    z_mids = 0.5 * (z_edges[:-1] + z_edges[1:])
    # plot
    ax = plt.subplot(gs[0, indt])
    cmap = get_cmap(COLOR_TRACER_GRADIENT[tracer])
    norm = plt.Normalize(vmin=z_edges[0], vmax=z_edges[-1])
    for (z1, z2), zmid in zip(zbins, z_mids):
        dv_rep, qu = get_repeats_dv(tracer, z1, z2, kind='Z1/Z2')
        # dv, qu = get_repeats_dv(tracer[:3], z1, z2, kind='Z1/Z2')
        # dv= sample_from_cdf_v2(tracer, z1, z2, len(dv_rep), seed = 1)
        dv = dv_rep
        dv = dv[np.abs(dv) <= cthr]
        ax.hist(dv, bins= set_edges('linear', cthr, 50), histtype='step', density=True,
                label = f'{tracer[:3]}' if np.isclose(z2, zmax) else None, lw = 0.8, color= cmap(norm(zmid))) 
    # plot axes settings
    ax.set_xlabel(r'$\Delta v_{i\,j} \, \rm{[km/s]}$', fontsize=11)
    ax.set_yscale('log')
    if indt == 0:
        ax.set_ylabel(r'Normalized counts', fontsize = 12)
    if indt > 0:
        ax.tick_params(axis='y', which='both', left=False, labelleft=False)
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=ax, pad=0.01, fraction=0.05, aspect=22, location='top')
    cbar.ax.tick_params(labelsize=10)
    cbar.ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
    # if tracer == 'QSO':
    # cbar.set_label(r'$z_{\mathrm{bin}}$', fontsize=12)
    ax.set_xlim(-cthr*1.1, +cthr*1.1)
    # ax.legend(fontsize=12, loc=2)
if save_fig == True:
    plt.savefig(OVERLEAF_DIR+f'/hist_repeats_linear_zbin.pdf', bbox_inches='tight')

# %%
# plot the overall dv distribution
fig = plt.figure(figsize=(18, 3))
gs = gridspec.GridSpec(1,4,wspace=0.12,hspace=0.1)

tracers = ['BGS', 'LRG', 'ELG', 'QSO']
for idx, tracer in enumerate(tracers):
    (zmin, zmax) = REDSHIFT_BIN_GLOBAL[tracer[:3]]
    color = COLOR_OVERALL[tracer[:3]]
    ax = plt.subplot(gs[idx])
    dv, qu = get_repeats_dv(tracer[:3], zmin, zmax, kind='Z1/Z2')
    cthr = qu['cthr']
    catasmin, catasmax, catasbin = np.log10(cthr)-1.25, 6, 0.1
    bins = np.arange(catasmin, catasmax, catasbin)
    dv = np.abs(dv)
    dvlog = np.log10(dv[dv>100])
    # ===== main panel (log10 |dv|) =====
    ax.hist(dvlog, histtype='step', bins= bins, label = f'{tracer[:3]} z{zmin}-{zmax}', lw = 1.4, color= color, density=True) 
    ax.axvline(np.log10(cthr), color='black', linestyle='-', linewidth=1.2, label = f'cthr={cthr}') # catastrophic therehold
    # plot axes settings
    ax.legend(loc='upper center', bbox_to_anchor=(0.25, 1.175), fontsize=12)
    ax.set_xlabel(r'$dv_{i\,j} \, \rm{[km/s]}$', fontsize=11)
    ax.set_yscale('log')
    ax.legend()
    if idx == 0:
        ax.set_ylabel(r'Number counts', fontsize = 11)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: fr"$10^{{{int(x)}}}$"))
    # ax.set_xlim(-cthr, +cthr)

# %%
# the assymetric distribution of dv
for tracer in ['LRG','ELG','QSO']:
    step = 0.1
    if tracer in ['QSO']: step=0.2
    (zmin, zmax) = REDSHIFT_BIN_GLOBAL[tracer[:3]]
    catasmin, catasmax, catasbin = 1.0, 6, 0.2
    bins = np.arange(catasmin, catasmax, catasbin)
    zrange = np.round(np.arange(zmin, zmax+ step/2, step), 1)
    zbins = list(zip(zrange[:-1], zrange[1:]))
    fig = plt.figure(figsize=(20, 3))
    gs = gridspec.GridSpec(1,len(zbins),wspace=0.05,hspace=0.1)
    for indz, (z1, z2) in enumerate(zbins):
        dv,_ = get_repeats_dv(tracer[:3], z1, z2, 'Z1/Z2')
        dv_pos = dv[dv > 0]
        dv_neg = dv[dv < 0]
        ax = plt.subplot(gs[indz])
        ax.hist(np.log10(dv_pos), bins=bins, histtype='step', lw=1.4, color='red',  label=f'dv > 0')
        ax.hist(np.log10(-dv_neg), bins=bins, histtype='step', lw=1.4, color='blue', label=f'dv < 0') 
        ax.set_yscale("log")
        if indz>0:
            ax.set_yticklabels([])
        ax.set_title(f'{tracer} z{z1}-{z2}')
        if indz==0:
            ax.legend()

# %% [markdown]
# ## Z-dependence

# %%
# tracers = ['BGS','LRG', 'ELG', 'QSO', 'QSO_3cut']
tracers = ['BGS_cdf', 'LRG_cdf', 'ELG_cdf', 'QSO_cdf', 'QSO_DR1']
# tracers = ['QSO', 'QSO_cdf']

step = 0.1

# var_method = 'bootstrap' # bootstrap, jackknife
# metrics_fn = RESULT_DIR+f'/repeat_metrics_{var_method}.csv'
# metrics_tab = Table.read(metrics_fn, format="csv")

markers = ['o', 's', '^', 'D', 'v', '*', 'x', 'P']
fig = plt.figure(figsize=(15, 3.6))
gs = gridspec.GridSpec(1,3,width_ratios=[1, 1, 1],wspace=0.28,hspace=0.,)
for idxt, tracer in enumerate(tracers):
    (zmin, zmax) = REDSHIFT_BIN_GLOBAL[tracer[:3]]
    zrange = np.round(np.arange(zmin, zmax+ step/2, step), 1)
    zbins = list(zip(zrange[:-1], zrange[1:]))
    color = COLOR_OVERALL[tracer[:3]]
    marker = markers[idxt]
    zmid_list, mad_list, rms_list, fc_list = [], [], [], []
    for indz, (z1, z2) in enumerate(zbins):
        if 'cdf' in tracer:
            N = 400000
            dv = sample_from_cdf_v2(tracer[:3], z1, z2, N)
            qu = get_dv_qu(dv, get_cthr(tracer[:3]))
        else:
            if 'DR1' in tracer:
                survey = 'Y1'
                verspec = 'iron'
            else:
                survey = 'DA2'
                verspec = 'loa-v1'
            dv, qu = get_repeats_dv(tracer[:3], z1, z2, kind='Z1/Z2', use_lss=True, survey=survey, verspec=verspec)
            qu['rms'] = qu['rms']/np.sqrt(2)
            qu['mad'] = qu['mad']/2
            qu['fc'] = qu['fc']/2
        # var = metrics_tab[metrics_tab["tracer"] == f"{tracer[:3]}_z{z1}_{z2}"]
        zmid_list.append((z1 + z2) / 2)
        mad_list.append((qu['mad'], 0)) # in km/s
        rms_list.append((qu['rms'], 0)) # in km/s
        fc_list.append((qu['fc'], 0)) # in %
    # === Plot panels ===
    metric_lists = [mad_list, rms_list, fc_list]
    qlabels = ['mad_std', 'rms_std','fc_std']
    olabels = ['mad','rms','fc']
    ylabels = [r"MAD [km/s]", r"RMS [km/s]", r"$f_{\mathrm{c}}$ [%]"]
    for idxq, (vals, ylabel) in enumerate(zip(metric_lists, ylabels)):
        means, errs = zip(*vals)            # unzip -> two tuples
        ax = plt.subplot(gs[idxq])
        if 'cdf' in tracer:
            # ax.errorbar(zmid_list, means, yerr = errs, label = label, 
            #             marker= 'o' if 'cdf' in tracer else '^', markersize=3, 
            #             color = color, linestyle='none',)
            ax.plot(zmid_list, means, 
                    markersize=4, marker= 'o', color = color, lw=1.4)
        elif tracer == 'QSO_DR1': 
            ax.plot(zmid_list, means, 
                    markersize=4, marker= 's', color = '#BA86E0', lw=1.4, ls='--')
        # === add horizontal line for global value ===
        # yvalue = overall_values[tracer][olabels[idxq]]
        # yvar = metrics_tab[metrics_tab["tracer"] == f"{tracer[:3]}_z{zmin}_{zmax}"][qlabels[idxq]][0]
        # print(tracer, zmin, zmax, qlabels[idxq], f'{yvalue:.2f}±{yvar:.2f}')
        # ax.axhline(y=yvalue, color=color, linestyle='--', lw=1.4, alpha=0.6 if tracer == 'QSO_3cut' else 1.0)
        # ax.axhspan(yvalue-yvar, yvalue+yvar, color=color, alpha=0.3)
        # plot axes settings
        # ax.set_xlabel(r"$z_{\mathrm{bin}}$", fontsize=18)
        ax.set_xlabel("Redshift bin", fontsize=14)
        ax.set_ylabel(ylabel, fontsize=14)
        ax.tick_params(axis='both', labelsize=14)
        ax.grid(alpha=0.4)
        if idxq==0:
            legend_handles = []
            for tr in tracers[:4]:
                legend_handles += [Line2D([0], [0], color=COLOR_OVERALL[tr[:3]], lw=1.4, ls='-', label=tr[:3], markersize=4, marker= 'o'),]
            ax.legend(handles=legend_handles, loc=2, fontsize=13)
        if idxq == 1:
            legend_handles = []
            legend_handles += [Line2D([0], [0], color='purple', lw=1.4, ls='-', label='DR2 QSO', markersize=4, marker= 'o'),]
            legend_handles += [Line2D([0], [0], color='#BA86E0', lw=1.4, ls='--', label='DR1 QSO', markersize=4, marker= 's'),]
            ax.legend(handles=legend_handles, loc=2, fontsize=13)            
if save_fig == True:
    plt.savefig(OVERLEAF_DIR+f'/plot_z_dependence.pdf', bbox_inches='tight')
# Out:
# [000010.23]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_BGS_z0.1-0.2.npz to generate redshift errors
# [000010.28]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_BGS_z0.2-0.3.npz to generate redshift errors
# [000010.34]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_BGS_z0.3-0.4.npz to generate redshift errors
# [000010.43]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_LRG_z0.4-0.5.npz to generate redshift errors
# [000010.48]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_LRG_z0.5-0.6.npz to generate redshift errors
# [000010.54]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_LRG_z0.6-0.7.npz to generate redshift errors
# [000010.59]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_LRG_z0.7-0.8.npz to generate redshift errors
# [000010.64]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_LRG_z0.8-0.9.npz to generate redshift errors
# [000010.69]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_LRG_z0.9-1.0.npz to generate redshift errors
# [000010.75]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_LRG_z1.0-1.1.npz to generate redshift errors
# [000010.81]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_ELG_z0.8-0.9.npz to generate redshift errors
# [000010.86]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_ELG_z0.9-1.0.npz to generate redshift errors
# [000010.91]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_ELG_z1.0-1.1.npz to generate redshift errors
# [000010.97]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_ELG_z1.1-1.2.npz to generate redshift errors
# [000011.02]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_ELG_z1.2-1.3.npz to generate redshift errors
# [000011.07]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_ELG_z1.3-1.4.npz to generate redshift errors
# [000011.13]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_ELG_z1.4-1.5.npz to generate redshift errors
# [000011.18]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_ELG_z1.5-1.6.npz to generate redshift errors
# [000011.24]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z0.8-0.9.npz to generate redshift errors
# [000011.30]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z0.9-1.0.npz to generate redshift errors
# [000011.35]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z1.0-1.1.npz to generate redshift errors
# [000011.40]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z1.1-1.2.npz to generate redshift errors
# [000011.46]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z1.2-1.3.npz to generate redshift errors
# [000011.51]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z1.3-1.4.npz to generate redshift errors
# [000011.56]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z1.4-1.5.npz to generate redshift errors
# [000011.62]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z1.5-1.6.npz to generate redshift errors
# [000011.67]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z1.6-1.7.npz to generate redshift errors
# [000011.72]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z1.7-1.8.npz to generate redshift errors
# [000011.78]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z1.8-1.9.npz to generate redshift errors
# [000011.83]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z1.9-2.0.npz to generate redshift errors
# [000011.89]  07-07 08:16  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_QSO_z2.0-2.1.npz to generate redshift errors

# %% [markdown]
# ## Summary of redshift errors quantities table

# %%
tracers = ['BGS', 'LRG', 'ELG', 'QSO']

for tracer in tracers:
    RMS = []
    MAD = []
    FC = []
    (zmin, zmax) = REDSHIFT_BIN_GLOBAL[tracer[:3]]

    survey = 'DA2' # DA2, Y1
    verspec = 'loa-v1' # loa-v1, iron
    # dv_err = sample_from_cdf_v2(tracer, z1=zmin, z2=zmax, N=50000, survey=survey, verspec=verspec, seed=42)
    # RMS.append(get_dv_qu(dv_err, get_cthr(tracer))['rms'])
    # MAD.append(get_dv_qu(dv_err, get_cthr(tracer))['mad'])
    # FC.append(get_dv_qu(dv_err, get_cthr(tracer))['fc'])

    dv_rep, qu_rep = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z1', use_lss=True, survey=survey, verspec=verspec)
    RMS.append(qu_rep['rms']/np.sqrt(2))
    MAD.append(qu_rep['mad']/2)
    FC.append(qu_rep['fc']/2)

    dv_rep, qu_rep = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z2', use_lss=True, survey=survey, verspec=verspec)
    RMS.append(qu_rep['rms']/np.sqrt(2))
    MAD.append(qu_rep['mad']/2)
    FC.append(qu_rep['fc']/2)

    dv_rep, qu_rep = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z1/Z2', use_lss=True, survey=survey, verspec=verspec)
    RMS.append(qu_rep['rms']/np.sqrt(2))
    MAD.append(qu_rep['mad']/2)
    FC.append(qu_rep['fc']/2)

    # survey = 'Y1' # DA2, Y1
    # verspec = 'iron' # loa-v1, iron
    # dv_rep, qu_rep = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z1/Z2', use_lss=True, survey=survey, verspec=verspec)
    # RMS.append(qu_rep['rms']/np.sqrt(2))
    # MAD.append(qu_rep['mad']/2)
    # FC.append(qu_rep['fc']/2)

    # print(f"{tracer} MAD: {MAD}, RMS: {RMS}, FC: {FC}")
    # print(f"{tracer} MAD: {MAD}, RMS: {RMS}, FC: {FC}")
    print(f"{tracer} FC: {FC}")
# Out:
# BGS FC: [0.2762644909762206, 0.2967741935483871, 0.38617990834663507]
# LRG FC: [0.18845757179462644, 0.1947996725877263, 0.24977040234003814]
# ELG FC: [0.11489246114579228, 0.11403764221056831, 0.13379742531682107]
# QSO FC: [0.2952012291916028, 0.2886541922776514, 0.5219632376435768]

# %%
tracer = 'LRG'

RMS = []
MAD = []
FC = []
(zmin, zmax) = REDSHIFT_BIN_GLOBAL[tracer[:3]]

survey = 'DA2' # DA2, Y1
verspec = 'loa-v1' # loa-v1, iron
dv_err = sample_from_cdf_v2(tracer[:3], z1=zmin, z2=zmax, N=500000, survey=survey, verspec=verspec, seed=42)
RMS.append(get_dv_qu(dv_err, get_cthr(tracer))['rms'])
MAD.append(get_dv_qu(dv_err, get_cthr(tracer))['mad'])
FC.append(get_dv_qu(dv_err, get_cthr(tracer))['fc'])

dv_rep, qu_rep = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z1/Z2', use_lss=True, survey=survey, verspec=verspec)
RMS.append(qu_rep['rms']/np.sqrt(2))
MAD.append(qu_rep['mad']/2)
FC.append(qu_rep['fc']/2)

dv_rep, qu_rep = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z1', use_lss=True, survey=survey, verspec=verspec)
RMS.append(qu_rep['rms']/np.sqrt(2))
MAD.append(qu_rep['mad']/2)
FC.append(qu_rep['fc']/2)

# survey = 'Y1' # DA2, Y1
# verspec = 'iron' # loa-v1, iron
# dv_rep, qu_rep = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z1/Z2', use_lss=True, survey=survey, verspec=verspec)
# RMS.append(qu_rep['rms']/np.sqrt(2))
# MAD.append(qu_rep['mad']/2)
# FC.append(qu_rep['fc']/2)
# print(f"{tracer} MAD: {MAD}, RMS: {RMS}, FC: {FC}")

print(f"FC: {FC}")
# Out:
# [000360.58]  06-22 00:51  dv_tools                     INFO     use /global/cfs/cdirs/desi/users/shengyu/repeats/DA2/loa-v1/verr_mode/CDF_verr_nonparam_LRG_z0.4-1.1.npz to generate redshift errors
# FC: [0.1698, 0.24977040234003814, 0.18845757179462644]

# %%
tracers = ['QSO']

def _make_z_evol_edges(zmin, zmax, dz=0.1):
    zmin = float(zmin)
    zmax = float(zmax)
    edges = np.round(np.arange(zmin, zmax + 0.5 * dz, dz), 1)
    if edges.size < 2 or edges[0] >= edges[-1]:
        raise ValueError(f'Invalid z_evol edges for zrange=({zmin}, {zmax})')
    return edges

RMS_Y1 = []
MAD_Y1 = []

RMS_Y3 = []
MAD_Y3 = []

fc_Y1 = []
fc_Y1 = []

zmin = 0.8
zmax = 2.1

markers = ['o', 's', '^', 'D', 'v', '*', 'x', 'P']
fig = plt.figure(figsize=(10, 3))
gs = gridspec.GridSpec(1,2,width_ratios=[1, 1],wspace=0.3,hspace=0.,)

for indt, tracer in enumerate(tracers):
    # cthr = get_cthr(tracer)
    # for (zmin, zmax) in REDSHIFT_BIN_LSS[tracer[:3]]:
    #     dv_rep, qu = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z1', use_lss=False, survey='DA2', verspec='loa-v1')
    #     print(zmin, zmax, get_dv_qu(dv_rep, 10000))

    #     dv_rep, qu = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z1', use_lss=False, survey='Y1', verspec='iron')
    #     print(zmin, zmax, get_dv_qu(dv_rep, 10000))
    # for (zmin, zmax) in REDSHIFT_BIN_ABACUSHF_V2[tracer[:3]]:

    edges = _make_z_evol_edges(zmin, zmax, dz=0.1)
    for z1, z2 in zip(edges[:-1], edges[1:]):
        dv_rep, qu = get_repeats_dv(tracer=tracer, zmin=z1, zmax=z2, kind='Z2', use_lss=False, survey='Y1', verspec='iron')
        RMS_Y1.append(get_dv_qu(dv_rep, 10000)['rms']/np.sqrt(2))
        MAD_Y1.append(get_dv_qu(dv_rep, 10000)['med']/np.sqrt(2))

        dv_rep, qu = get_repeats_dv(tracer=tracer, zmin=z1, zmax=z2, kind='Z2', use_lss=False, survey='DA2', verspec='loa-v1')
        RMS_Y3.append(get_dv_qu(dv_rep, 10000)['rms']/np.sqrt(2))
        MAD_Y3.append(get_dv_qu(dv_rep, 10000)['med']/np.sqrt(2))

    ax=plt.subplot(gs[0])
    ax.plot(edges[:-1]+0.05, MAD_Y3, marker=markers[0],color='maroon', label='DA2-loa-v1')
    ax.plot(edges[:-1]+0.05, MAD_Y1, marker=markers[2],color='darkblue', label='DA1-iron')
    ax.set_ylabel('MAD [km/s]', fontsize=12)
    ax.set_xlabel(r'$z_{\rm{bin}}$', fontsize=12)
    ax.legend(loc=2, fontsize=11)

    ax=plt.subplot(gs[1])
    ax.plot(edges[:-1]+0.05, RMS_Y3, marker=markers[0],color='maroon', label='DA2-loa-v1')
    ax.plot(edges[:-1]+0.05, RMS_Y1, marker=markers[2],color='darkblue', label='DA1-iron')
    ax.set_xlabel(r'$z_{\rm{bin}}$', fontsize=12)
    ax.set_ylabel('RMS [km/s]', fontsize=12)

# %%
tracers = ['QSO']

def _make_z_evol_edges(zmin, zmax, dz=0.1):
    zmin = float(zmin)
    zmax = float(zmax)
    edges = np.round(np.arange(zmin, zmax + 0.5 * dz, dz), 1)
    if edges.size < 2 or edges[0] >= edges[-1]:
        raise ValueError(f'Invalid z_evol edges for zrange=({zmin}, {zmax})')
    return edges


zmin = 0.8
zmax = 2.1

plt.figure(figsize=(12, 6))
gs = gridspec.GridSpec(2,2,width_ratios=[1, 1], height_ratios=[1, 1], wspace=0.2,hspace=0.25,)

for indt, tracer in enumerate(tracers):
    # cthr = get_cthr(tracer)
    # for (zmin, zmax) in REDSHIFT_BIN_LSS[tracer[:3]]:
    #     dv_rep, qu = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z1', use_lss=False, survey='DA2', verspec='loa-v1')
    #     print(zmin, zmax, get_dv_qu(dv_rep, 10000))

    #     dv_rep, qu = get_repeats_dv(tracer=tracer, zmin=zmin, zmax=zmax, kind='Z1', use_lss=False, survey='Y1', verspec='iron')
    #     print(zmin, zmax, get_dv_qu(dv_rep, 10000))
    # for (zmin, zmax) in REDSHIFT_BIN_ABACUSHF_V2[tracer[:3]]:

    edges = _make_z_evol_edges(zmin, zmax, dz=0.1)
    for idc, cthr in enumerate([3000, 10000]):
        RMS_Y1 = []
        RMS_Y3 = []
        MAD_Y1 = []
        MAD_Y3 = []
        fc_Y1 = []
        fc_Y3 = []

        for z1, z2 in zip(edges[:-1], edges[1:]):
            dv_rep, qu = get_repeats_dv(tracer=tracer, zmin=z1, zmax=z2, kind='Z2', use_lss=False, survey='Y1', verspec='iron')
            RMS_Y1.append(get_dv_qu(dv_rep, cthr)['rms']/np.sqrt(2))
            MAD_Y1.append(get_dv_qu(dv_rep, cthr)['med']/np.sqrt(2))
            fc_Y1.append(get_dv_qu(dv_rep, 10000)['fc'])

            dv_rep, qu = get_repeats_dv(tracer=tracer, zmin=z1, zmax=z2, kind='Z2', use_lss=False, survey='DA2', verspec='loa-v1')
            RMS_Y3.append(get_dv_qu(dv_rep, cthr)['rms']/np.sqrt(2))
            MAD_Y3.append(get_dv_qu(dv_rep, cthr)['med']/np.sqrt(2))
            fc_Y3.append(get_dv_qu(dv_rep, 10000)['fc'])

        ax = plt.subplot(gs[idc])
        ax.plot(edges[:-1]+0.05, RMS_Y1, marker=markers[2], label=f'DA1-iron (vcut={cthr})')
        ax.plot(edges[:-1]+0.05, RMS_Y3, marker=markers[0], label=f'DA2-loa-v1 (vcut={cthr})')
        ax.set_xlabel(r'$z_{\rm{bin}}$', fontsize=14)
        ax.set_ylabel(f'Repeats RMS/√2', fontsize=12)
        ax.legend(loc=2, fontsize=10)

    ax=plt.subplot(gs[2])
    ax.plot(edges[:-1]+0.05, MAD_Y1, marker=markers[2], label='DA1-iron')
    ax.plot(edges[:-1]+0.05, MAD_Y3, marker=markers[0], label='DA2-loa-v1')
    ax.set_ylabel('Repeats MAD/√2', fontsize=12)
    ax.set_xlabel(r'$z_{\rm{bin}}$', fontsize=12)
    ax.legend(loc=2, fontsize=11)

    ax=plt.subplot(gs[3])
    ax.plot(edges[:-1]+0.05, fc_Y1, marker=markers[2], label=f'DA1-iron (vcut={cthr})')
    ax.plot(edges[:-1]+0.05, fc_Y3, marker=markers[0], label=f'DA2-loa-v1 (vcut={cthr})')
    ax.set_ylabel('Repeats fc', fontsize=12)
    ax.set_xlabel(r'$z_{\rm{bin}}$', fontsize=12)
    ax.legend(loc=2, fontsize=11)

# %%
tracer = 'QSO'


dv_rep_y1, qu = get_repeats_dv(tracer=tracer, zmin=1.6, zmax=1.8, kind='Z2', use_lss=False, survey='Y1', verspec='iron')
dv_rep_y2, qu = get_repeats_dv(tracer=tracer, zmin=1.6, zmax=1.8, kind='Z2', use_lss=False, survey='DA2', verspec='loa-v1')

plt.figure(figsize=(5, 4))
plt.hist(np.log10(np.abs(dv_rep_y1)), bins=50, histtype='step', label='DA1-iron', density=True, lw=1.5) 
plt.hist(np.log10(np.abs(dv_rep_y2)), bins=50, histtype='step', label='DA2-loa-v1', density=True, lw=1.5)
plt.axvline(np.log10(3000), color='darkblue', linestyle='--', linewidth=1.2, label='vcut=3000') # catastrophic therehold
plt.axvline(np.log10(10000), color='maroon', linestyle='--', linewidth=1.2, label='vcut=10000') # catastrophic therehold

plt.title(f'{tracer} repeats z1.6-1.8', fontsize=12)
plt.yscale('log')
plt.legend(loc=2, fontsize=9)

# %% [markdown]
# ## Estimate the error bar for redshift errors -- variance from the sample

# %%
tracers = ['BGS', 'LRG', 'ELG', 'QSO']
for idx, tracer in enumerate(tracers):
    (zmin, zmax) = REDSHIFT_BIN_GLOBAL[tracer[:3]]
    dv, qu = get_repeats_dv(tracer[:3], zmin, zmax)
    cthr = qu['cthr']
    print(tracer, 'z_t=(z1+z2)/2',(zmin, zmax), f"MED:{qu['med']:.3f}", f"RMS:{qu['rms']:.3f}", f"fc:{qu['fc']:.3f}%")

    dv, qu = get_repeats_dv(tracer[:3], zmin, zmax, zture = 'Z1')
    cthr = qu['cthr']
    print(tracer, 'z_t=z1',(zmin, zmax), f"MED:{qu['med']:.3f}", f"RMS:{qu['rms']:.3f}", f"fc:{qu['fc']:.3f}%")

    dv, qu = get_repeats_dv(tracer[:3], zmin, zmax, zture = 'Z2')
    cthr = qu['cthr']
    print(tracer, 'z_t=z2',(zmin, zmax), f"MED:{qu['med']:.3f}", f"RMS:{qu['rms']:.3f}", f"fc:{qu['fc']:.3f}%")

    print("\n")
# Out:
# BGS z_t=(z1+z2)/2 (0.1, 0.4) MED:13.958 RMS:33.967 fc:0.521%
# BGS z_t=z1 (0.1, 0.4) MED:13.961 RMS:33.970 fc:0.528%
# BGS z_t=z2 (0.1, 0.4) MED:13.965 RMS:33.974 fc:0.545%
#
#
# LRG z_t=(z1+z2)/2 (0.4, 1.1) MED:42.699 RMS:82.125 fc:0.547%
# LRG z_t=z1 (0.4, 1.1) MED:42.648 RMS:82.124 fc:0.459%
# LRG z_t=z2 (0.4, 1.1) MED:42.659 RMS:82.151 fc:0.476%
#
#
# ELG z_t=(z1+z2)/2 (0.8, 1.6) MED:9.000 RMS:27.968 fc:0.238%
# ELG z_t=z1 (0.8, 1.6) MED:8.999 RMS:27.967 fc:0.232%
# ELG z_t=z2 (0.8, 1.6) MED:8.999 RMS:27.963 fc:0.231%
#
#
# QSO z_t=(z1+z2)/2 (0.8, 2.1) MED:95.817 RMS:468.270 fc:0.943%
# QSO z_t=z1 (0.8, 2.1) MED:95.375 RMS:471.241 fc:0.606%
# QSO z_t=z2 (0.8, 2.1) MED:95.375 RMS:473.648 fc:0.596%

# %%
metrics_fn = RESULT_DIR+'/repeat_metrics_bootstrap.csv'
tab = Table.read(metrics_fn, format="csv")
tab
# Out:
# <Table length=35>
#    tracer      N      method  ...       fc_mean              fc_std
#    str12     int64     str9   ...       float64             float64
# ------------ ------ --------- ... ------------------- --------------------
# BGS_z0.1_0.4 362943 bootstrap ...  0.5088953361822656 0.011830193631791901
# BGS_z0.1_0.2 126256 bootstrap ...  0.3223609175009504 0.015799489502442903
# BGS_z0.2_0.3 140779 bootstrap ...  0.6023625682807805  0.02057302899878659
# BGS_z0.3_0.4  95908 bootstrap ...  0.6183008716686824 0.025222898388513666
# LRG_z0.4_1.1 207651 bootstrap ...  0.4594247078029964 0.014740598993853264
# LRG_z0.4_0.5  22137 bootstrap ...  0.3613859149839635  0.04073660814483661
# LRG_z0.5_0.6  29570 bootstrap ...  0.5444707473791005 0.042371754059203334
# LRG_z0.6_0.7  35593 bootstrap ... 0.42705026269210233  0.03462485584213658
# LRG_z0.7_0.8  40449 bootstrap ...  0.5661450221266285  0.03729112418152568
# LRG_z0.8_0.9  40561 bootstrap ...  0.3426937205690195 0.029259470234466338
#          ...    ...       ... ...                 ...                  ...
# QSO_z1.1_1.2  16694 bootstrap ...  0.6349586677848329  0.06176691433104654
# QSO_z1.2_1.3  17523 bootstrap ...  0.7647092392855105  0.06581774895567936
# QSO_z1.3_1.4  18232 bootstrap ...  0.4552435278630978  0.04987934959040941
# QSO_z1.4_1.5  19090 bootstrap ...  0.9114719748559456  0.06814877294529549
# QSO_z1.5_1.6  20042 bootstrap ...   0.818281608621894  0.06341099176815865
# QSO_z1.6_1.7  25251 bootstrap ...    0.45938774701992   0.0422264141581083
# QSO_z1.7_1.8  25317 bootstrap ... 0.40289133783623654 0.039663896017995866
# QSO_z1.8_1.9  24265 bootstrap ...  0.3544199464248918 0.038302076662120696
# QSO_z1.9_2.0  22307 bootstrap ... 0.35414892186309227  0.03947886211634854
# QSO_z2.0_2.1  29247 bootstrap ... 0.32823879372243303  0.03393113911582771

# %%
metrics_fn = RESULT_DIR+'/repeat_metrics_jackknife.csv'
tab = Table.read(metrics_fn, format="csv")
tab
# Out:
# <Table length=35>
#    tracer      N      method  ...       fc_mean              fc_std
#    str12     int64     str9   ...       float64             float64
# ------------ ------ --------- ... ------------------- --------------------
# BGS_z0.1_0.4 362943 jackknife ...  0.5091708615402418  0.01181420988848367
# BGS_z0.1_0.2 126256 jackknife ...  0.3223609175009505  0.01595312506781737
# BGS_z0.2_0.3 140779 jackknife ...  0.6023625682807806 0.020622894666594654
# BGS_z0.3_0.4  95908 jackknife ...  0.6183008716686823  0.02531208877647946
# LRG_z0.4_1.1 207651 jackknife ...  0.4594247078029965 0.014840252125890857
# LRG_z0.4_0.5  22137 jackknife ... 0.36138591498396355   0.0403320109994505
# LRG_z0.5_0.6  29570 jackknife ...  0.5444707473791002   0.0427940533268422
# LRG_z0.6_0.7  35593 jackknife ...  0.4270502626921025  0.03456479509836124
# LRG_z0.7_0.8  40449 jackknife ...  0.5661450221266288   0.0373063241059704
# LRG_z0.8_0.9  40561 jackknife ...  0.3426937205690194 0.029017411741762675
#          ...    ...       ... ...                 ...                  ...
# QSO_z1.1_1.2  16694 jackknife ...  0.6349586677848331 0.061478369399919394
# QSO_z1.2_1.3  17523 jackknife ...  0.7647092392855106  0.06580962316295776
# QSO_z1.3_1.4  18232 jackknife ... 0.45524352786309785 0.049856965130325163
# QSO_z1.4_1.5  19090 jackknife ...  0.9114719748559451  0.06878468605745881
# QSO_z1.5_1.6  20042 jackknife ...  0.8182816086218937   0.0636366802093686
# QSO_z1.6_1.7  25251 jackknife ... 0.45938774701992025 0.042555839891913055
# QSO_z1.7_1.8  25317 jackknife ... 0.40289133783623676   0.0398125309248385
# QSO_z1.8_1.9  24265 jackknife ...   0.354419946424892  0.03815108546890527
# QSO_z1.9_2.0  22307 jackknife ...  0.3541489218630923  0.03977514059953496
# QSO_z2.0_2.1  29247 jackknife ...  0.3282387937224331  0.03344627700478867

# %% [markdown]
# ## APPENDIX

# %%
# save the repeat number table
rows = []

for tracer in ['BGS','LRG', 'ELG', 'QSO']:
    step = 0.1
    (zmin, zmax) = REDSHIFT_BIN_GLOBAL[tracer[:3]]
    ds, _ = get_repeats_dv(tracer[:3], zmin, zmax)
    ds_pos = ds[ds > 0]
    ds_neg = ds[ds < 0]
    tag = f'{tracer}_{zmin}_{zmax}'
    N   = len(ds)
    N_p = len(ds_pos)
    N_n = len(ds_neg)
    # save this overall row
    rows.append((tag, N, N_p, N_n))
    # loop over dz bins
    zrange = np.round(np.arange(zmin, zmax + step/2, step), 1)
    zbins = list(zip(zrange[:-1], zrange[1:]))
    for indz, (z1, z2) in enumerate(zbins):
        ds, _ = get_repeats_dv(tracer[:3], z1, z2)
        tag = f'{tracer}_{z1}_{z2}'
        ds_pos = ds[ds > 0]
        ds_neg = ds[ds < 0]
        N   = len(ds)
        N_p = len(ds_pos)
        N_n = len(ds_neg)
        # save per-bin row
        rows.append((tag, N, N_p, N_n))
    for (z1, z2) in REDSHIFT_BIN_ABACUSHF_V2[tracer[:3]]:
        ds, _ = get_repeats_dv(tracer[:3], z1, z2)
        tag = f'{tracer}_{z1}_{z2}'
        ds_pos = ds[ds > 0]
        ds_neg = ds[ds < 0]
        N   = len(ds)
        N_p = len(ds_pos)
        N_n = len(ds_neg)
        # save per-bin row
        rows.append((tag, N, N_p, N_n))

# make output table
outtab = Table(rows=rows, names=('tag','N','N_p','N_n'))
outfile = os.path.join(RESULT_DIR, "repeat_numbers.csv")
outtab.write(outfile, overwrite=True, format='ascii.csv')

# %%
tracers = ['BGS','LRG', 'ELG', 'QSO', 'QSO_3cut']
step = 0.1

var_method = 'bootstrap' # bootstrap, jackknife
metrics_fn = RESULT_DIR+f'/repeat_metrics_{var_method}.csv'
metrics_tab = Table.read(metrics_fn, format="csv")

overall_values = {
    'BGS': [13.3, 36.0, 0.51],
    'LRG': [40.7, 82.1, 0.46],
    'ELG': [8.6, 28.2, 0.23],
    'QSO': [91.0, 471.2, 0.61],
    'QSO_3cut': [91.0, 391.0, 0.97]
} # med_mean, rms_mean, fc_mean

markers = ['o', 's', '^', 'D', 'v', '*', 'x', 'P']
fig = plt.figure(figsize=(18, 3))
gs = gridspec.GridSpec(1,4,width_ratios=[1, 1, 1, 1],
                       wspace=0.24,hspace=0.1,left=0.05, right=0.98, top=0.95, bottom=0.05)
for idxt, tracer in enumerate(tracers):
    (zmin, zmax) = REDSHIFT_BIN_OVERALL[tracer[:3]]
    zrange = np.round(np.arange(zmin, zmax+ step/2, step), 1)
    zbins = list(zip(zrange[:-1], zrange[1:]))
    color = COLOR_OVERALL[tracer[:3]]
    marker = markers[idxt]
    zmid_list, median_list, rms_list, fc_list = [], [], [], []
    for indz, (z1, z2) in enumerate(zbins):
        dv = GET_REPEATS_DV(tracer[:3], z1, z2)
        # ===== quantities of dv =====
        cthr = GET_CTHR(tracer)
        dv_smear = dv[abs(dv) < cthr]
        median_dv = np.median(abs(dv))
        RMS = np.sqrt(np.mean(dv_smear**2))    
        fc= np.mean(abs(dv) >= cthr)*100 # fc = (np.sum(abs(dv) > cthr)) /len(dv)*100
        var = metrics_tab[metrics_tab["tracer"] == f"{tracer[:3]}_z{z1}_{z2}"]
        zmid_list.append((z1 + z2) / 2)
        median_list.append((median_dv, var['med_std'][0])) # in km/s
        rms_list.append((RMS, var['rms_std'][0])) # in km/s
        fc_list.append((fc, var['fc_std'][0])) # in %
    # === Plot panels ===
    metric_lists = [median_list, rms_list, fc_list]
    qlabels = ['med_std', 'rms_std','fc_std']
    ylabels = [r"Median [km/s]", r"RMS [km/s]", r"$f_{\mathrm{catas}}$ [%]"]
    for idxq, (vals, ylabel) in enumerate(zip(metric_lists, ylabels)):
        means, errs = zip(*vals)            # unzip -> two tuples
        ax = plt.subplot(gs[idxq])
        # ax.scatter(zmid_list, means, color=color, s=30, label=tracer)
        ax.errorbar(zmid_list, means, yerr = errs, label = tracer, 
                    marker= '^' if tracer == 'QSO_3cut' else 'o', markersize=3, 
                    color = color, linestyle='none',)
        if idxt == 4:
            ax.plot(zmid_list, means, color=color, lw=1.2, alpha=0.6, ls=':')
        else:
            ax.plot(zmid_list, means, color=color, lw=1.2, alpha=0.6)
        # === add horizontal line for global value ===
        yvalue = overall_values[tracer][idxq]
        yvar = metrics_tab[metrics_tab["tracer"] == f"{tracer[:3]}_z{zmin}_{zmax}"][qlabels[idxq]][0]
        ax.axhline(y=yvalue, color=color, linestyle='--', lw=1.4, alpha=0.6 if tracer == 'QSO_3cut' else 1.0)
        # ax.axhspan(yvalue-yvar, yvalue+yvar, color=color, alpha=0.3)
        # plot axes settings
        ax.set_xlabel(r"$z_{\mathrm{bin}}$", fontsize=14)
        ax.set_ylabel(ylabel, fontsize=12)
        ax.tick_params(axis='both', labelsize=11)
        ax.grid(alpha=0.3)
        if idxq==0 and idxt==3:
            ax.legend(fontsize=12, loc='best', frameon=False)
    # ===== 4th panel — QSO: PDF of v_smear vs z =====
    tracerh = 'QSO'
    if tracer == tracerh:
        axh = plt.subplot(gs[3])
        # build z bins
        z_edges = zrange
        z_mids  = 0.5 * (z_edges[:-1] + z_edges[1:])
        n_z     = len(zbins)
        # linear dv bins
        cthr = 10000 if tracerh == 'QSO' else 1000
        dv_edges = np.linspace(-cthr, cthr, 60)
        dv_centers = 0.5 * (dv_edges[:-1] + dv_edges[1:])
        # colormap to encode redshift
        cmap = plt.cm.Greens
        norm = plt.Normalize(vmin=z_edges[0], vmax=z_edges[-1])
        for (z1, z2), zmid in zip(zbins, z_mids):
            dv = GET_REPEATS_DV('QSO', z1, z2)
            dv_smear = dv[abs(dv) < cthr]
            # counts, _ = np.histogram(dv_smear, bins=dv_edges, density=True)
            # axh.plot(
            #     dv_centers, counts,
            #     color=cmap(norm(zmid)), lw=1.2,
            #     label=f"{zmid:.1f}" if zmid in z_mids[::3] else None  # fewer labels
            # )
            axh.hist(
                dv_smear, bins=dv_edges, 
                histtype='step', density=True,
                color=cmap(norm(zmid)), lw=1.2,
                label=f"{zmid:.1f}" if zmid in z_mids[::3] else None  # fewer labels
            )
        # plot axes settings
        axh.set_xlabel(r"$ \Delta v_{\mathrm{smear}} \, [\mathrm{km/s}]$", fontsize=12)
        axh.set_ylabel(r"QSO PDF", fontsize=12)
        axh.set_yscale('log')   # log-y usually helps span the tail
        axh.set_xlim(-cthr+1000, cthr-1000)
        axh.tick_params(axis='both', labelsize=11)
        axh.grid(alpha=0.3)
        axh.set_ylim(10**(-7.), 10**(-1.8))
        # colorbar for redshift
        sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
        sm.set_array([])
        cbar = fig.colorbar(sm, ax=axh, pad=0.01)
        cbar.set_label(r"$z_{\mathrm{bin}}$", fontsize=15)
# if save_fig == True:
    # plt.savefig(OVERLEAF_DIR+f'/plot_z_dependence', dpi=300, bbox_inches='tight')

# %%
def bootstrap_metrics(dv, cthr, B=1000, seed=1234):
    """
    Estimate median(|dv|), RMS(core), and fc using bootstrap resampling.

    Parameters
    ----------
    dv : array Δv values (km/s) for one tracer or z-bin
    cthr : float Catastrophic threshold (e.g., 1000 or 10000 km/s)
    B : int Number of bootstrap resamples

    Returns
    -------
    dict with medians and 16-84% confidence intervals.
    """
    rng = np.random.default_rng(seed)
    dv_abs = np.abs(dv)
    N = len(dv_abs)

    med, rms, fc = np.empty(B), np.empty(B), np.empty(B)
    for b in range(B):
        idx = rng.integers(0, N, N)
        x = dv_abs[idx]
        core = x[x < cthr]
        med[b] = np.median(x)
        rms[b] = np.sqrt(np.mean(core**2)) if core.size else np.nan
        fc[b]  = np.mean(x >= cthr)*100
    out = {
        'median': {'mean': np.nanmean(med), 'std': np.nanstd(med, ddof=1)},
        'rms':    {'mean': np.nanmean(rms), 'std': np.nanstd(rms, ddof=1)},
        'fc':     {'mean': np.nanmedian(fc),  'std': np.nanstd(fc, ddof=1)}
    }
    return out

def jackknife_metrics(dv, cthr):
    """
    Delete-1 jackknife variance for median(|dv|), RMS(core), and fc.

    Parameters
    ----------
    dv : array Δv values (km/s)
    cthr : float Catastrophic threshold (km/s)

    Returns
    -------
    dict with mean and ±1σ jackknife errors.
    """
    dv_abs = np.abs(dv)
    N = len(dv_abs)
    if N <= 1:
        return {k:(np.nan,(np.nan,np.nan)) for k in ['median','rms','fc']}
    med, rms, fc = np.empty(N), np.empty(N), np.empty(N)

    med_loo = loo_medians_fast(dv_abs) # sort once and no need for loop
    for i in range(N):
        x = np.delete(dv_abs, i)
        core = x[x < cthr]
        # med[i] = np.median(x) # use the function loo_medians_fast without loop
        rms[i] = np.sqrt(np.mean(core**2)) if core.size else np.nan
        fc[i]  = np.mean(x >= cthr)*100
    def jk_std(arr):
        G = len(arr)
        mean = np.nanmean(arr)
        var = (G - 1) / G * np.nansum((arr - mean)**2)
        return np.sqrt(var)
    med_mean, rms_mean, fc_mean = map(np.nanmean, [med_loo, rms, fc])
    med_err,  rms_err,  fc_err  = map(jk_std, [med, rms, fc])
    out = {
        'median': {'mean': med_mean, 'std': med_err},
        'rms':    {'mean': rms_mean, 'std': rms_err},
        'fc':     {'mean': fc_mean,  'std': fc_err}
    }
    return out

def loo_medians_fast(a):
    """
    Return the N delete-1 medians of array a in O(N log N).
    """
    a = np.asarray(a)
    N  = a.size
    # Sort once and map each element to its rank
    order = np.argsort(a, kind='mergesort')   # stable; any kind works here
    y     = a[order]                          # sorted values
    rank  = np.empty(N, dtype=int)
    rank[order] = np.arange(N)
    if N % 2 == 0:
        # N = 2k → N-1 odd → median is element at index k-1 of y' (y with one removed)
        k = N // 2
        # If you remove something left of k, the (k-1)th of y' is y[k]; else it's y[k-1]
        med_loo = np.where(rank < k, y[k], y[k-1]).astype(float)
    else:
        # N = 2k+1 → N-1 even → median is average of indices (k-1, k) in y'
        k = N // 2
        left  = (y[k-1] + y[k])   * 0.5      # remove right side (r ≥ k+1)
        mid   = (y[k-1] + y[k+1]) * 0.5      # remove one of the middle pair (r == k)
        right = (y[k]   + y[k+1]) * 0.5      # remove left side (r ≤ k-1)
        med_loo = np.empty(N, dtype=float)
        med_loo[rank <= k-1] = right
        med_loo[rank == k]   = mid
        med_loo[rank >= k+1] = left
    return med_loo

# %%
dv_abs = np.abs(dv)
N = len(dv_abs)
med, rms, fc = np.empty(N), np.empty(N), np.empty(N)
med_loo = loo_medians_fast(dv_abs) # sort once and no need for loop
for i in range(N):
    x = np.delete(dv_abs, i)
    core = x[x < 1000]
    med[i] = np.median(x)

# %%
set(med_loo==med)
# Out:
# {True}

# %%
tracers = ['LRG','ELG','QSO']
step = 0.1

var_method = 'bootstrap' # bootstrap, jackknife
metrics_fn = RESULT_DIR+f'/repeat_metrics_{var_method}.csv'
metrics_tab = Table.read(metrics_fn, format="csv")

overall_values = {
    'BGS': [13.3, 36.0, 0.51],
    'LRG': [40.7, 82.1, 0.46],
    'ELG': [8.6, 28.2, 0.23],
    'QSO': [91.0, 471.2, 0.61],
    'QSO_3cut': [91.0, 391.0, 0.97]
} # med_mean, rms_mean, fc_mean

markers = ['o', 's', '^', 'D', 'v', '*', 'x', 'P']
fig = plt.figure(figsize=(15, 3))
gs = gridspec.GridSpec(1,3,width_ratios=[1, 1, 1],
                       wspace=0.22,hspace=0.1,left=0.05, right=0.98, top=0.95, bottom=0.05)

for inverse in [True, False]:
    for idxt, tracer in enumerate(tracers):
        (zmin, zmax) = REDSHIFT_BIN_OVERALL[tracer[:3]]

        ### overall quantity ###
        dv = GET_REPEATS_DV(tracer[:3], zmin, zmax, inverse=inverse)
        cthr_ol = GET_CTHR(tracer)
        dv_smear_ol = dv[abs(dv) < cthr_ol]
        median_dv_ol = np.median(abs(dv))
        RMS_ol = np.sqrt(np.mean(dv_smear_ol**2))    
        fc_ol= np.mean(abs(dv) >= cthr_ol)*100 # fc = (np.sum(abs(dv) > cthr)) /len(dv)*100
        ###  zbin ###
        zrange = np.round(np.arange(zmin, zmax+ step/2, step), 1)
        zbins = list(zip(zrange[:-1], zrange[1:]))

        color = COLOR_OVERALL[tracer[:3]]
        if inverse==True: color = 'purple'

        marker = markers[idxt]
        zmid_list, median_list, rms_list, fc_list = [], [], [], []
        for indz, (z1, z2) in enumerate(zbins):
            dv = GET_REPEATS_DV(tracer[:3], z1, z2, inverse=inverse)
            # ===== quantities of dv =====
            cthr = GET_CTHR(tracer)
            dv_smear = dv[abs(dv) < cthr]
            median_dv = np.median(abs(dv))
            RMS = np.sqrt(np.mean(dv_smear**2))    
            fc= np.mean(abs(dv) >= cthr)*100 # fc = (np.sum(abs(dv) > cthr)) /len(dv)*100
            var = metrics_tab[metrics_tab["tracer"] == f"{tracer[:3]}_z{z1}_{z2}"]
            zmid_list.append((z1 + z2) / 2)
            median_list.append((median_dv, var['med_std'][0])) # in km/s
            rms_list.append((RMS, var['rms_std'][0])) # in km/s
            fc_list.append((fc, var['fc_std'][0])) # in %
        # === Plot panels ===
        metric_lists = [median_list, rms_list, fc_list]
        qlabels = ['med_std', 'rms_std','fc_std']
        ylabels = [r"Median [km/s]", r"RMS [km/s]", r"$f_{\mathrm{catas}}$ [%]"]
        for idxq, (vals, ylabel) in enumerate(zip(metric_lists, ylabels)):
            means, errs = zip(*vals)            # unzip -> two tuples
            ax = plt.subplot(gs[idxq])
            # ax.scatter(zmid_list, means, color=color, s=30, label=tracer)
            ax.errorbar(zmid_list, means, yerr = errs,
                        marker= '^' if tracer == 'QSO_3cut' else 'o', markersize=3, 
                        color = color, linestyle='none',)
            if tracer == 'QSO_3cut':
                # label = r'$v_{\rm{cut}}$ = 3000' if idxq==1 else None
                ax.plot(zmid_list, means, color=color, lw=1.2, alpha=0.8, ls=':')
            else:
                # label = r'$v_{\rm{cut}}$ = 10000' if tracer == 'QSO' and idxq==1 else None
                label = f'Inverse z1-z2' if inverse==True and tracer=='QSO' else None
                ax.plot(zmid_list, means, color=color, lw=1.2, alpha=0.8, label =label)
            # plot axes settings
            ax.set_xlabel(r"$z_{\mathrm{bin}}$", fontsize=14)
            ax.set_ylabel(ylabel, fontsize=12)
            ax.tick_params(axis='both', labelsize=11)
            ax.grid(alpha=0.4)
            # if idxq==0 and tracer== 'QSO':
                # ax.legend(fontsize=12, loc='best', frameon=False)
            if idxq==1:
                ax.legend(fontsize=12, loc='best', frameon=False)

        for idxy, yvalue in enumerate([median_dv_ol, RMS_ol, fc_ol]):
            ax = plt.subplot(gs[idxy])
            ax.axhline(y=yvalue, color=color, linestyle='--', lw=1.4, alpha=0.6)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Save the target_IDS from the LSS catalogs

# %%
survey = 'Y1'
verspec = 'iron'

for tracer in tracers:
    path = f'/dvs_ro/cfs/cdirs/desi/survey/catalogs/{survey}/LSS/{verspec}/LSScats/v1.5'
    if tracer =='BGS': tracer_label = 'BGS_BRIGHT-21.5'
    elif tracer == 'ELG': tracer_label = 'ELG_LOPnotqso'
    else: tracer_label = tracer
    lss_data = Catalog.read(path+f'/{tracer_label}_clustering.dat.fits')
    target_id = lss_data['TARGETID']

    output_dir = f'/global/cfs/cdirs/desi/users/shengyu/repeats/{survey}/{verspec}'
    output_fn = f'{output_dir}/{tracer}_target_ids.npy'
    np.save(output_fn, target_id)
    print(f'Saved {tracer} target IDs to {output_fn}')
# Out:
# Saved BGS target IDs to /global/cfs/cdirs/desi/users/shengyu/repeats/Y1/iron/BGS_target_ids.npy
# Saved LRG target IDs to /global/cfs/cdirs/desi/users/shengyu/repeats/Y1/iron/LRG_target_ids.npy
# Saved ELG target IDs to /global/cfs/cdirs/desi/users/shengyu/repeats/Y1/iron/ELG_target_ids.npy
# Saved QSO target IDs to /global/cfs/cdirs/desi/users/shengyu/repeats/Y1/iron/QSO_target_ids.npy
